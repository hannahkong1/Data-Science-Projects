# %% [markdown]
# # Section 1: Obesity Dataset

# %% [markdown]
# ##### 1. What dataset did you choose and why? Why is it meaningful to you? How did you go about finding the dataset?

# %% [markdown]
# For this project, I chose a dataset that focused on the influence different independent variables, such as sleep quality, headache frequency, academic performance, study load, and extracurriculars, had on that student's stress levels. I chose this dataset because I relate to it as a student who has a high study load and suffers from chronic stress. This dataset is meaningful to me because the different independent variables are ones that I closely resonate with. For example, I get alot of headaches whenever I get more stressed about school or just life in general. I know that for many students, stress is a big issue in their studies and daily life, so I think being able to study this dataset will help me understand what are the biggest triggers for stress. To find this dataset, I went on Kraggle and scrolled on their public datasets until I found something I had interest in and also had only numbers in the dataset. When I came upon this dataset, I looked over it to make sure that it consisted only of numbers so that it would be easy for me to find the correlation between different variables. I then downloaded it and uploaded it into the dataframe.

# %% [markdown]
# ##### 2. Load your dataset into Python

# %%
import pandas as pd
df = pd.read_csv("Student Stress Factors.csv")
df
# Out:
#               Timestamp  Kindly Rate your Sleep Quality 😴  \
# 0   27/10/2023 21:54:15                                 3
# 1   28/10/2023 12:24:40                                 4
# 2   28/10/2023 12:24:51                                 2
# 3   28/10/2023 12:26:11                                 3
# 4   28/10/2023 12:26:45                                 2
# 5   28/10/2023 12:31:02                                 3
# 6   28/10/2023 12:34:45                                 3
# 7   28/10/2023 12:35:43                                 4
# 8   28/10/2023 12:36:07                                 2
# 9   28/10/2023 12:36:20                                 1
# 10  28/10/2023 12:37:22                                 2
# 11  28/10/2023 12:38:40                                 3
# 12  28/10/2023 12:39:43                                 2
# 13  28/10/2023 12:40:50                                 4
# 14  28/10/2023 12:41:12                                 4
# ...

# %% [markdown]
# # Section 2: Exploratory Data Analysis

# %% [markdown]
# ##### What descriptive statistics will get a broad overview of this data?

# %% [markdown]
# To get a broad overview of this data, I will need to use linear regression to find the correlation coefficient between the different independent variables and stress levels. Finding the correlation coefficient between sleep quality and stress, headache frequency and stress, academic performance and stress, study load and stress, and extracurriculars and stress will allow me to determine the relationship between stress and the selected independent variable. I will also find the average academic performance and study load levels to determine whether or not this dataset is lacking exceptional students or struggling students.

# %% [markdown]
# ##### Now do the data analysis you discussed above.

# %%
numerical_cols = ["Kindly Rate your Sleep Quality 😴", "How many times a week do you suffer headaches 🤕?", "How would you rate you academic performance 👩‍🎓?", "how would you rate your study load?", "How many times a week you practice extracurricular activities 🎾?", "How would you rate your stress levels?"]

# %%
df_numerical = df[numerical_cols]

# %%
sleep_stress = df_numerical.corr()['Kindly Rate your Sleep Quality 😴']['How would you rate your stress levels?']
sleep_stress
# Out:
# 0.2869953743300688

# %%
headaches_stress = df_numerical.corr()['How many times a week do you suffer headaches 🤕?']['How would you rate your stress levels?']
headaches_stress
# Out:
# -0.03543948818522813

# %%
academic_stress = df_numerical.corr()['How would you rate you academic performance 👩‍🎓?']['How would you rate your stress levels?']
academic_stress
# Out:
# 0.005931822459612539

# %%
studyload_stress = df_numerical.corr()['how would you rate your study load?']['How would you rate your stress levels?']
studyload_stress
# Out:
# 0.3412321127385092

# %%
ecs_stress = df_numerical.corr()['How many times a week you practice extracurricular activities 🎾?']['How would you rate your stress levels?']
ecs_stress
# Out:
# 0.1805357736144858

# %%
df['how would you rate your study load?'].mean()
# Out:
# 2.811320754716981

# %%
df['How would you rate you academic performance 👩‍🎓?'].mean()
# Out:
# 3.2264150943396226

# %% [markdown]
# # Section 3: Exploratory Data Visualization

# %% [markdown]
# ##### Create one data visualization with your dataset.

# %%
df.plot.scatter(x = 'how would you rate your study load?', y = 'How would you rate your stress levels?' )
# Out:
# <Axes: xlabel='how would you rate your study load?', ylabel='How would you rate your stress levels?'>

# %% [markdown]
# ##### Summarize the results from your data visualization.

# %% [markdown]
# I created a scatterplot with stress levels as the dependent variable and study load as the independent variable. The scatterplot looks fairly uniform which leads me to believe that there is little relationship between stress levels and study load. This matches up with the estimate of the correlation between stress levels and study load concluded above. The correlation coefficient between these two variables was 0.3412 which tells me that there is a very weak, positive relationship between stress levels and study load. Logistically, this doesn't make sense because normally, when a student has more homework and more tests to study for, they are generally more stressed about finishing their homework on time and also performing well on tests. I would have expected the correlation to be higher, indicating that the higher one's study load, the higher their stress levels.

# %% [markdown]
# # Section 4: Data Science

# %% [markdown]
# ##### What are some questions you have about the dataset and how can you use Python to answer them?

# %% [markdown]
# What are the levels of sleep quality, headaches, academic performance, study load that the highest 5 stress levels in this dataset have?

# %% [markdown]
# Is there a relationship between sleep quality and study load?

# %%
df_numerical.corr()["Kindly Rate your Sleep Quality 😴"]["how would you rate your study load?"]
# Out:
# 0.09551840524676705

# %% [markdown]
# There is practically no relationship between a sampled student's sleep quality and their study load.

# %%
highest_5 = df.nlargest(5, "How would you rate your stress levels?")
highest_5
# Out:
#               Timestamp  Kindly Rate your Sleep Quality 😴  \
# 6   28/10/2023 12:34:45                                 3
# 26  28/10/2023 13:44:07                                 5
# 30  28/10/2023 13:57:20                                 5
# 32  28/10/2023 14:27:19                                 5
# 35  28/10/2023 15:10:02                                 5
#
#     How many times a week do you suffer headaches 🤕?  \
# 6                                                  5
# 26                                                 1
# 30                                                 1
# 32                                                 5
# 35                                                 1
#
#     How would you rate you academic performance 👩‍🎓?  \
# 6                                                  1
# 26                                                 5
# 30                                                 3
# 32                                                 4
# ...

# %% [markdown]
# What are the levels of sleep quality, headaches, academic performance, study load that the lowest 5 stress levels in this dataset have?

# %%
lowest_5 = df.nsmallest(5, "How would you rate your stress levels?")
lowest_5
# Out:
#               Timestamp  Kindly Rate your Sleep Quality 😴  \
# 5   28/10/2023 12:31:02                                 3
# 7   28/10/2023 12:35:43                                 4
# 8   28/10/2023 12:36:07                                 2
# 11  28/10/2023 12:38:40                                 3
# 13  28/10/2023 12:40:50                                 4
#
#     How many times a week do you suffer headaches 🤕?  \
# 5                                                  1
# 7                                                  3
# 8                                                  1
# 11                                                 1
# 13                                                 1
#
#     How would you rate you academic performance 👩‍🎓?  \
# 5                                                  3
# 7                                                  1
# 8                                                  4
# 11                                                 5
# ...

# %% [markdown]
# What does the scatterplot look like when the independent variable is sleep quality and the dependent variable is stress level?

# %%
df.plot.scatter(x = 'Kindly Rate your Sleep Quality 😴', y = 'How would you rate your stress levels?')
# Out:
# <Axes: xlabel='Kindly Rate your Sleep Quality 😴', ylabel='How would you rate your stress levels?'>

# %% [markdown]
# # Section 5: Overall Summary

# %% [markdown]
# ##### Summarize your dataset, findings, and visualization. (1-2 paragraphs)

# %% [markdown]
# The "Student Stress Factors" data records the responses of 51 students to questions regarding their stressed levels and possible factors. These factors include the student's sleep quality, how many times a week they get headaches, their academic perfomance, their study load, and the amount of time they spend on extracurriculars. Based on the responses of these sampled participants recorded in the this dataset, I discovered the correlations between sleep quality, academic performance, study load, headaches, or extracurriculars and that student's stress levels. By finding the correlation coefficient between each independent variable and the dependent variable, I discovered that among this sample, sleep quality had a very weak, positive, linear relationship with one's stress levels. I concluded this because the two variables had a correlation coefficient of 0.287, which is positive and close to zero. I also concluded that there was practically no relationship between frequency of heaches and stress levels because the correlation coefficient for these two variables was -0.0354, which is too close to zero for me to claim that headaches and stress levels are correlated. The correlation coefficient between academic performance and stress levels was 0.00593 which allows me to conclude that, within this sample, there is also no correlation between a student's academic performance and their stress levels. The correlation coefficient between study load and stress levels was 0.341 which tells me that there is a weak, positive, and linear relationship between these two variables. Lastly, the correlation coefficient between time spent on extracurriculars and stress levels was 0.18 which also tells me that there is a very weak relationship between these two variables. These findings also line up with the 2 scatterplots I created above. The scatterplot with stress level as the y-variable and study load as the x-variable shows to be fairly uniform which would allow me to conclude that study load and stress levels have a very weak positive relationship which is confirmed by the correlation coefficient. The second scatterplot with stress level as the y-variable and sleep quality as the x-variable is fairly uniform as well, allowing me to conclude that their is a weak relationship between the two which is backed up by the calculated correlation coefficient.
#
# Overall, I would steer away from generalizing this sample's results to a larger population of students. For one, the sample is only 51 students which is simply too small to make accurate generalizations to the population. Additionally, alot of the results from this dataset don't logistically make sense. According to the results in this lab, study load and academic performance have little to no correlation with a student's stress levels. Speaking from personal experience, having a heavier study load would increase my stress levels because I have an excessive amount of work to do and not enough time to do it which would mean that there would be a strong relationship between study load and my stress levels. I also find that when I perform better academically, it means I am spending more time studying which increases my stress levels because there is so much to study in such a small time frame. This would also yield a strong positive relationship between my academic performance and my stress levels. I think that for the average student, these are both the case for them. However, the students in this sample have little correlation between study load, academic performance and stress levels. I think this inconsistency might be due to a sample that is not representative enough or too small. In conclusion, I would avoid generalizing the results I found from this dataset to a larger population.
